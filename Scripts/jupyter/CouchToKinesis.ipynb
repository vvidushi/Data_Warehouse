# %% [markdown]
# # read data from couchdb in paralell structure

# %% [markdown]
# # couch db connection

# %%
import pandas as pd
import couchdb
import requests
from io import StringIO
import math

# %%
db_name = <db>
couch = couchdb.Server(<couch server>)
if db_name in couch:
    db = couch[db_name]
    print(f"Connected to existing database: {db_name}")
else:
    db = couch.create(db_name)
    print(f"Created new database: {db_name}")
# Out:
# ✅ Connected to existing database: oecd_health_expenditure

# %% [markdown]
# ## read from couch

# %%
print(f"Connected to database: {db.name} ({len(db)} documents)")
# Out:
# Connected to database: oecd_health_expenditure (4570 documents)

# %% [markdown]
# # defaultdict(list) is a special type of dictionary in Python, provided by the collections module, that automatically creates an empty list as the value for any new key you access

# %%
from collections import defaultdict

structure_groups = defaultdict(list)
structure_groups
# Out:
# defaultdict(list, {})

# %%
for doc_id in db:
    doc = db[doc_id]
    if 'structure_name' in doc:
        structure_name = doc['structure_name']
        structure_groups[structure_name].append(doc)

# %%
structure_shortcuts = {
    'Gross fixed capital formation in the healthcare system': 'HealthGFCF',
    'Healthcare coverage': 'HC_Coverage',
    'Health expenditure and financing': 'HEF_Main',
    'Input costs for healthcare providers': 'HP_cost',
    'Revenues of healthcare financing schemes' :'HCF_Revenue'
}

# %%
structure_groups = {}
for doc_id in db:
    doc = db[doc_id]
    if 'structure_name' in doc:
        group = doc['structure_name']
        if group not in structure_groups:
            structure_groups[group] = []
        clean_doc = {k: v for k, v in doc.items() if k not in ['_id', '_rev']}
        structure_groups[group].append(clean_doc)

# %% [markdown]
# # debug for revenue

# %% [markdown]
# structure_groups

# %%
structure_groups.keys()
# Out:
# dict_keys(['Gross fixed capital formation in the healthcare system', 'Health expenditure and financing', 'Revenues of healthcare financing schemes', 'Input costs for healthcare providers', 'Healthcare coverage'])

# %% [markdown]
# # Create DataFrames with shortcut variable names

# %%
for group_name, shortcut in structure_shortcuts.items():
    df = pd.DataFrame(structure_groups.get(group_name, []))
    globals()[shortcut] = df  # This creates variables like HealthGFCF, HC_Coverage, etc.
    print(f"Created DataFrame: {shortcut} ({len(df)} rows)")
# Out:
# ✅ Created DataFrame: HealthGFCF (1000 rows)
# ✅ Created DataFrame: HC_Coverage (1000 rows)
# ✅ Created DataFrame: HEF_Main (1000 rows)
# ✅ Created DataFrame: HP_cost (1000 rows)
# ✅ Created DataFrame: HCF_Revenue (570 rows)

# %%
HEF_Main.head()
# Out:
#   STRUCTURE                     STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 1  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 2  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 3  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 4  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
#
#                      STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0  Health expenditure and financing      I      USA  United States    A
# 1  Health expenditure and financing      I      USA  United States    A
# 2  Health expenditure and financing      I      IND          India    A
# 3  Health expenditure and financing      I      IND          India    A
# 4  Health expenditure and financing      I      IND          India    A
#
#   Frequency of observation     MEASURE      Measure  ... OBS_STATUS  \
# 0                   Annual  EXP_HEALTH  Expenditure  ...       None
# 1                   Annual  EXP_HEALTH  Expenditure  ...       None
# 2                   Annual  EXP_HEALTH  Expenditure  ...       None
# 3                   Annual  EXP_HEALTH  Expenditure  ...       None
# 4                   Annual  EXP_HEALTH  Expenditure  ...       None
#
#   Observation status OBS_STATUS2 Observation status 2 OBS_STATUS3  \
# 0               None        None                 None        None
# 1               None        None                 None        None
# 2               None        None                 None        None
# 3               None        None                 None        None
# 4               None        None                 None        None
#
#   Observation status 3 UNIT_MULT Unit multiplier DECIMALS Decimals
# 0                 None         0           Units        1      One
# 1                 None         0           Units        1      One
# 2                 None         0           Units        1      One
# 3                 None         0           Units        1      One
# 4                 None         0           Units        1      One
#
# [5 rows x 46 columns]

# %% [markdown]
# # now based on STRUCTURE_NAME push data into kinesis in parallel from all 4 df

# %%
import boto3
import json
import time

kinesis = boto3.client(
    'kinesis',
    aws_access_key_id=<key_id>,
    aws_secret_access_key=<access_key>,
    region_name=<region>
)

stream_name = <kinesis stream_name>

# %% [markdown]
# # s3 bucket mapping

# %%
bucket_mapping = {
    'HealthGFCF': 'health-gfcf-data',
    'HC_Coverage': 'health-coverage-data',
    'HEF_Main': 'health-expenditure-data',
    'HP_cost': 'health-provider-costs',
    'HCF_Revenue':'health-financing-Revenue'
}

# %% [markdown]
# # limit to send

# %%
HealthGFCF = HealthGFCF.head(5)
HC_Coverage = HC_Coverage.head(5)
HEF_Main = HEF_Main.head(5)
HP_cost = HP_cost.head(5)
HCF_Revenue=HCF_Revenue.head(5)
HCF_Revenue
# Out:
#   structure                        structure_id  \
# 0  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA_FS(1.0)
# 1  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA_FS(1.0)
# 2  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA_FS(1.0)
# 3  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA_FS(1.0)
# 4  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA_FS(1.0)
#
#                              structure_name action country_code  \
# 0  Revenues of healthcare financing schemes      I          JPN
# 1  Revenues of healthcare financing schemes      I          PER
# 2  Revenues of healthcare financing schemes      I          PER
# 3  Revenues of healthcare financing schemes      I          CHN
# 4  Revenues of healthcare financing schemes      I          CHN
#
#                    country_name freq frequency_of_observation   measure  \
# 0                         Japan    A                   Annual  Revenues
# 1                          Peru    A                   Annual  Revenues
# 2                          Peru    A                   Annual  Revenues
# 3  China (People’s Republic of)    A                   Annual  Revenues
# 4  China (People’s Republic of)    A                   Annual  Revenues
#
#   unit_measure  ...      asset_type      price_base  year   value unit_mult  \
# 0    PT_EXP_FS  ...  Not applicable  Not applicable  2017  46.161         0
# 1    PT_EXP_FS  ...  Not applicable  Not applicable  2019  28.434         0
# 2    PT_EXP_FS  ...  Not applicable  Not applicable  2022  23.332         0
# 3    PT_EXP_FS  ...  Not applicable  Not applicable  2017  29.028         0
# 4    PT_EXP_FS  ...  Not applicable  Not applicable  2021  27.210         0
#
#   unit_multiplier decimals                   doc_type  \
# 0           Units      One  health_financing_revenues
# 1           Units      One  health_financing_revenues
# 2           Units      One  health_financing_revenues
# 3           Units      One  health_financing_revenues
# 4           Units      One  health_financing_revenues
#
#                                dataset_name         processed_timestamp
# 0  Revenues of Healthcare Financing Schemes  2025-04-21T13:20:25.756183
# 1  Revenues of Healthcare Financing Schemes  2025-04-21T13:20:25.756213
# 2  Revenues of Healthcare Financing Schemes  2025-04-21T13:20:25.756434
# 3  Revenues of Healthcare Financing Schemes  2025-04-21T13:20:25.758545
# 4  Revenues of Healthcare Financing Schemes  2025-04-21T13:20:25.758568
#
# [5 rows x 32 columns]

# %%
DATASETS = {
    'HealthGFCF': HealthGFCF,
    'HC_Coverage': HC_Coverage,
    'HEF_Main': HEF_Main,
    'HP_cost': HP_cost,
    'HCF_Revenue':HCF_Revenue
}

# %% [markdown]
# #  # Initialize Kinesis client

# %%
import json
import boto3
from concurrent.futures import ThreadPoolExecutor

# Configuration
KINESIS_STREAM = <KINESIS_STREAM>
AWS_REGION = <AWS_REGION>



kinesis = boto3.client(
    'kinesis',
    aws_access_key_id=<key_id>,
    aws_secret_access_key=<access_key>,
    region_name=<region_name>
)

# %% [markdown]
# # send data

# %%
def send_dataset_to_kinesis(dataset_name, df, sample_size=None):
    print(f"Starting {dataset_name} stream ({len(df)} records)")
    
    if sample_size:
        df = df.head(sample_size)
        print(f"Running in sample mode (first {sample_size} records)")

    for idx, record in df.iterrows():
        try:
            payload = json.dumps(record.to_dict())            
            kinesis.put_record(
                StreamName=KINESIS_STREAM,
                Data=payload,
                PartitionKey=dataset_name  
            )
            
            if idx % 100 == 0:
                print(f"{dataset_name}: Sent record {idx}/{len(df)}")

        except Exception as e:
            print(f" {dataset_name} error at record {idx}: {str(e)}")
    
    print(f"Completed {dataset_name} stream")
with ThreadPoolExecutor(max_workers=4) as executor:
    futures = []
    for name, df in DATASETS.items():
        futures.append(
            executor.submit(
                send_dataset_to_kinesis,
                dataset_name=name,
                df=df,
                sample_size=None  
            )
        )
    
    for future in futures:
        future.result()
# Out:
# 🚀 Starting HealthGFCF stream (1000 records)🚀 Starting HC_Coverage stream (1000 records)
#
# 🚀 Starting HEF_Main stream (1000 records)
# 🚀 Starting HP_cost stream (1000 records)
# 📤 HC_Coverage: Sent record 0/1000
# 📤 HEF_Main: Sent record 0/1000
# 📤 HealthGFCF: Sent record 0/1000
# 📤 HP_cost: Sent record 0/1000
# 📤 HC_Coverage: Sent record 100/1000
# 📤 HealthGFCF: Sent record 100/1000
# 📤 HEF_Main: Sent record 100/1000
# 📤 HP_cost: Sent record 100/1000
# 📤 HealthGFCF: Sent record 200/1000
# 📤 HEF_Main: Sent record 200/1000
# 📤 HC_Coverage: Sent record 200/1000
# 📤 HP_cost: Sent record 200/1000
# 📤 HealthGFCF: Sent record 300/1000
# 📤 HEF_Main: Sent record 300/1000
# 📤 HC_Coverage: Sent record 300/1000
# 📤 HP_cost: Sent record 300/1000
# 📤 HealthGFCF: Sent record 400/1000
# 📤 HEF_Main: Sent record 400/1000
# 📤 HP_cost: Sent record 400/1000
# 📤 HC_Coverage: Sent record 400/1000
# 📤 HealthGFCF: Sent record 500/1000
# 📤 HEF_Main: Sent record 500/1000
# 📤 HP_cost: Sent record 500/1000
# 📤 HC_Coverage: Sent record 500/1000
# 📤 HealthGFCF: Sent record 600/1000
# 📤 HEF_Main: Sent record 600/1000
# 📤 HP_cost: Sent record 600/1000
# 📤 HC_Coverage: Sent record 600/1000
# 📤 HealthGFCF: Sent record 700/1000
# 📤 HEF_Main: Sent record 700/1000
# 📤 HP_cost: Sent record 700/1000
# 📤 HC_Coverage: Sent record 700/1000
# 📤 HealthGFCF: Sent record 800/1000
# 📤 HEF_Main: Sent record 800/1000
# 📤 HP_cost: Sent record 800/1000
# 📤 HC_Coverage: Sent record 800/1000
# 📤 HEF_Main: Sent record 900/1000
# 📤 HealthGFCF: Sent record 900/1000
# 📤 HP_cost: Sent record 900/1000
# 📤 HC_Coverage: Sent record 900/1000
# ✅ Completed HealthGFCF stream
# 🚀 Starting HCF_Revenue stream (570 records)
# ✅ Completed HEF_Main stream
# 📤 HCF_Revenue: Sent record 0/570
# ✅ Completed HC_Coverage stream
# ✅ Completed HP_cost stream
# 📤 HCF_Revenue: Sent record 100/570
# 📤 HCF_Revenue: Sent record 200/570
# 📤 HCF_Revenue: Sent record 300/570
# 📤 HCF_Revenue: Sent record 400/570
# 📤 HCF_Revenue: Sent record 500/570
# ✅ Completed HCF_Revenue stream

# %% [markdown]
# # debugging

# %% [markdown]
# # test with one record

# %%
rec = HealthGFCF.iloc[0]
payload = json.dumps(rec.to_dict())

kinesis.put_record(
    StreamName=KINESIS_STREAM,
    Data=payload,
    PartitionKey="random name"  
)
# Out:
# {'ShardId': 'shardId-000000000000',
#  'SequenceNumber': '49662528673383861570870701425129547993620313263833088002',
#  'ResponseMetadata': {'RequestId': 'd75c647e-9726-36df-b722-c82382f0d9d4',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd75c647e-9726-36df-b722-c82382f0d9d4',
#    'x-amz-id-2': 'sHjr1piQ7hEtFGplyvJFXwFNt8Gu1zsABV+LHtobfwOyEFPYxq3F4ZXki3NXShEIjb3+xbM7YJmeGGyTAugt7VMC3lBvETHX',
#    'date': 'Sun, 20 Apr 2025 08:02:37 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '110',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %%
readCheck()
# Out:
# {"user_id": 101, "location": "San Francisco", "temperature": 67.5, "timestamp": 1745098732.5864081}
# {"user_id": 101, "location": "San Francisco", "temperature": 67.5, "timestamp": 1745099953.5145624}
# {"user_id": 101, "location": "San Francisco", "temperature": 67.5, "timestamp": 1745100003.6269653}
# {"user_id": 101, "location": "San Francisco", "temperature": 67.5, "timestamp": 1745105435.4470923}
# {"STRUCTURE": "DATAFLOW", "STRUCTURE_ID": "OECD.ELS.HD:DSD_SHA@DF_SHA_HK(1.0)", "STRUCTURE_NAME": "Gross fixed capital formation in the healthcare system", "ACTION": "I", "REF_AREA": "ESP", "Reference area": "Spain", "FREQ": "A", "Frequency of observation": "Annual", "MEASURE": "CAPITAL_FORM", "Measure": "Gross fixed capital formation", "UNIT_MEASURE": "PT_B1GQ", "Unit of measure": "Percentage of GDP", "FINANCING_SCHEME": "_Z", "Financing scheme": "Not applicable", "FINANCING_SCHEME_REV": "_Z", "Revenues of financing schemes": "Not application", "FUNCTION": "_Z", "Health function": "Not applicable", "MODE_PROVISION": "_Z", "Mode of provision": "Not applicable", "PROVIDER": "_T", "Health care provider": "Total", "FACTOR_PROVISION": "_Z", "Factor of provision": "Not applicable", "ASSET_TYPE": "_T", "Asset type": "Total", "PRICE_BASE": "_Z", "Price base": "Not applicable", "TIME_PERIOD": 2000, "Time period": null, "OBS_VALUE": 0.216, "Observation value": null, "BASE_PER": null, "Base period": null, "CURRENCY": null, "Currency": null, "OBS_STATUS": null, "Observation status": null, "OBS_STATUS2": null, "Observation status 2": null, "OBS_STATUS3": null, "Observation status 3": null, "UNIT_MULT": 0, "Unit multiplier": "Units", "DECIMALS": 1, "Decimals": "One"}
# {"STRUCTURE": "DATAFLOW", "STRUCTURE_ID": "OECD.ELS.HD:DSD_SHA@DF_SHA_HK(1.0)", "STRUCTURE_NAME": "Gross fixed capital formation in the healthcare system", "ACTION": "I", "REF_AREA": "ESP", "Reference area": "Spain", "FREQ": "A", "Frequency of observation": "Annual", "MEASURE": "CAPITAL_FORM", "Measure": "Gross fixed capital formation", "UNIT_MEASURE": "PT_B1GQ", "Unit of measure": "Percentage of GDP", "FINANCING_SCHEME": "_Z", "Financing scheme": "Not applicable", "FINANCING_SCHEME_REV": "_Z", "Revenues of financing schemes": "Not application", "FUNCTION": "_Z", "Health function": "Not applicable", "MODE_PROVISION": "_Z", "Mode of provision": "Not applicable", "PROVIDER": "_T", "Health care provider": "Total", "FACTOR_PROVISION": "_Z", "Factor of provision": "Not applicable", "ASSET_TYPE": "_T", "Asset type": "Total", "PRICE_BASE": "_Z", "Price base": "Not applicable", "TIME_PERIOD": 2000, "Time period": null, "OBS_VALUE": 0.216, "Observation value": null, "BASE_PER": null, "Base period": null, "CURRENCY": null, "Currency": null, "OBS_STATUS": null, "Observation status": null, "OBS_STATUS2": null, "Observation status 2": null, "OBS_STATUS3": null, "Observation status 3": null, "UNIT_MULT": 0, "Unit multiplier": "Units", "DECIMALS": 1, "Decimals": "One"}
# {"STRUCTURE": "DATAFLOW", "STRUCTURE_ID": "OECD.ELS.HD:DSD_SHA@DF_SHA_HK(1.0)", "STRUCTURE_NAME": "Gross fixed capital formation in the healthcare system", "ACTION": "I", "REF_AREA": "ESP", "Reference area": "Spain", "FREQ": "A", "Frequency of observation": "Annual", "MEASURE": "CAPITAL_FORM", "Measure": "Gross fixed capital formation", "UNIT_MEASURE": "PT_B1GQ", "Unit of measure": "Percentage of GDP", "FINANCING_SCHEME": "_Z", "Financing scheme": "Not applicable", "FINANCING_SCHEME_REV": "_Z", "Revenues of financing schemes": "Not application", "FUNCTION": "_Z", "Health function": "Not applicable", "MODE_PROVISION": "_Z", "Mode of provision": "Not applicable", "PROVIDER": "_T", "Health care provider": "Total", "FACTOR_PROVISION": "_Z", "Factor of provision": "Not applicable", "ASSET_TYPE": "_T", "Asset type": "Total", "PRICE_BASE": "_Z", "Price base": "Not applicable", "TIME_PERIOD": 2000, "Time period": null, "OBS_VALUE": 0.216, "Observation value": null, "BASE_PER": null, "Base period": null, "CURRENCY": null, "Currency": null, "OBS_STATUS": null, "Observation status": null, "OBS_STATUS2": null, "Observation status 2": null, "OBS_STATUS3": null, "Observation status 3": null, "UNIT_MULT": 0, "Unit multiplier": "Units", "DECIMALS": 1, "Decimals": "One"}

# %% [markdown]
# #  Test parallel load for sample 5 records

# %%
HealthGFCF = HealthGFCF.head(5)
HC_Coverage = HC_Coverage.head(5)
HEF_Main = HEF_Main.head(5)
HP_cost = HP_cost.head(5)

# %%
DATASETS = {
    'HealthGFCF': HealthGFCF,
    'HC_Coverage': HC_Coverage,
    'HEF_Main': HEF_Main,
    'HP_cost': HP_cost
}

# %%
HC_Coverage
# Out:
#   STRUCTURE                                     STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 1  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 2  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 3  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 4  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
#
#         STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0  Healthcare coverage      I      NLD    Netherlands    A
# 1  Healthcare coverage      I      NLD    Netherlands    A
# 2  Healthcare coverage      I      NLD    Netherlands    A
# 3  Healthcare coverage      I      NLD    Netherlands    A
# 4  Healthcare coverage      I      NLD    Netherlands    A
#
#   Frequency of observation MEASURE                    Measure  ...  \
# 0                   Annual     HIC  Health insurance coverage  ...
# 1                   Annual     HIC  Health insurance coverage  ...
# 2                   Annual     HIC  Health insurance coverage  ...
# 3                   Annual     HIC  Health insurance coverage  ...
# 4                   Annual     HIC  Health insurance coverage  ...
#
#   TIME_PERIOD Time period OBS_VALUE Observation value  OBS_STATUS  \
# 0        2010        None      99.6              None           E
# 1        2011        None      99.6              None           E
# 2        2012        None      99.7              None           E
# 3        2013        None      99.8              None           E
# 4        2014        None      99.8              None           E
#
#   Observation status  UNIT_MULT Unit multiplier DECIMALS Decimals
# 0    Estimated value          0           Units     None     None
# 1    Estimated value          0           Units     None     None
# 2    Estimated value          0           Units     None     None
# 3    Estimated value          0           Units     None     None
# 4    Estimated value          0           Units     None     None
#
# [5 rows x 24 columns]
