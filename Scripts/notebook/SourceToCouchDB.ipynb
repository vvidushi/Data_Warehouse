# %%
# Install required libraries
# !pip install pandas couchdb requests
# Out:
# Requirement already satisfied: pandas in /Users/vidushi/myenv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: couchdb in /Users/vidushi/myenv/lib/python3.13/site-packages (1.2)
# Requirement already satisfied: requests in /Users/vidushi/myenv/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/vidushi/myenv/lib/python3.13/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vidushi/myenv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/vidushi/myenv/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vidushi/myenv/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vidushi/myenv/lib/python3.13/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vidushi/myenv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vidushi/myenv/lib/python3.13/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vidushi/myenv/lib/python3.13/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Users/vidushi/myenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Import libraries
import pandas as pd
import couchdb
import requests
from io import StringIO
import math

# %% [markdown]
# # Step 1: Connect to CouchDB

# %%
# Update your credentials if needed
db_name = 'oecd_health_expenditure'  # Same database where you uploaded earlier 4620 docs
couch = couchdb.Server('http://admin:admin@localhost:5984/')
# http://127.0.0.1:5984/_utils/#/_all_dbs
if db_name in couch:


    db = couch[db_name]
    print(f"✅ Connected to existing database: {db_name}")
else:
    db = couch.create(db_name)
    print(f"✅ Created new database: {db_name}")
# Out:
# ✅ Connected to existing database: oecd_health_expenditure

# %% [markdown]
# # Step 2: Fetch First Dataset (Health Protection that was uploaded earlier)

# %%
# (Assuming you have it locally or you re-fetch it again)
url_protection = (
    "https://sdmx.oecd.org/public/rest/data/"
    "OECD.ELS.HD,DSD_HEALTH_PROT@DF_HEALTH_PROT,1.0/"
    "all?startPeriod=2010&dimensionAtObservation=AllDimensions&format=csvfilewithlabels"
)

headers = {
    "User-Agent": "Mozilla/5.0"
}

# Fetch and read Health Protection dataset
response_protection = requests.get(url_protection, headers=headers)
response_protection.raise_for_status()

df_protection = pd.read_csv(StringIO(response_protection.text))
df_protection
print(f"✅ Health Protection dataset: {df_protection.shape[0]} rows, {df_protection.shape[1]} columns.")
# Out:
# ✅ Health Protection dataset: 4620 rows, 24 columns.

# %%
df_protection
# Out:
#      STRUCTURE                                     STRUCTURE_ID  \
# 0     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 1     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 2     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 3     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 4     DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# ...        ...                                              ...
# 4615  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 4616  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 4617  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 4618  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
# 4619  DATAFLOW  OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)
#
#            STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0     Healthcare coverage      I      NLD    Netherlands    A
# 1     Healthcare coverage      I      NLD    Netherlands    A
# 2     Healthcare coverage      I      NLD    Netherlands    A
# 3     Healthcare coverage      I      NLD    Netherlands    A
# 4     Healthcare coverage      I      NLD    Netherlands    A
# ...                   ...    ...      ...            ...  ...
# 4615  Healthcare coverage      I      BGR       Bulgaria    A
# 4616  Healthcare coverage      I      BGR       Bulgaria    A
# 4617  Healthcare coverage      I      BGR       Bulgaria    A
# 4618  Healthcare coverage      I      BGR       Bulgaria    A
# 4619  Healthcare coverage      I      BGR       Bulgaria    A
#
#      Frequency of observation MEASURE                    Measure  ...  \
# 0                      Annual     HIC  Health insurance coverage  ...
# 1                      Annual     HIC  Health insurance coverage  ...
# 2                      Annual     HIC  Health insurance coverage  ...
# 3                      Annual     HIC  Health insurance coverage  ...
# 4                      Annual     HIC  Health insurance coverage  ...
# ...                       ...     ...                        ...  ...
# 4615                   Annual     HIC  Health insurance coverage  ...
# 4616                   Annual     HIC  Health insurance coverage  ...
# 4617                   Annual     HIC  Health insurance coverage  ...
# 4618                   Annual     HIC  Health insurance coverage  ...
# 4619                   Annual     HIC  Health insurance coverage  ...
#
#      TIME_PERIOD Time period OBS_VALUE Observation value  OBS_STATUS  \
# 0           2010         NaN      99.6               NaN           E
# 1           2011         NaN      99.6               NaN           E
# 2           2012         NaN      99.7               NaN           E
# 3           2013         NaN      99.8               NaN           E
# 4           2014         NaN      99.8               NaN           E
# ...          ...         ...       ...               ...         ...
# 4615        2019         NaN      88.6               NaN           A
# 4616        2020         NaN      88.0               NaN           A
# 4617        2021         NaN      88.2               NaN           A
# 4618        2022         NaN      93.5               NaN           A
# 4619        2023         NaN      93.9               NaN           A
#
#       Observation status  UNIT_MULT  Unit multiplier DECIMALS Decimals
# 0        Estimated value          0            Units      NaN      NaN
# 1        Estimated value          0            Units      NaN      NaN
# 2        Estimated value          0            Units      NaN      NaN
# 3        Estimated value          0            Units      NaN      NaN
# 4        Estimated value          0            Units      NaN      NaN
# ...                  ...        ...              ...      ...      ...
# 4615        Normal value          0            Units      NaN      NaN
# 4616        Normal value          0            Units      NaN      NaN
# 4617        Normal value          0            Units      NaN      NaN
# 4618        Normal value          0            Units      NaN      NaN
# 4619        Normal value          0            Units      NaN      NaN
#
# [4620 rows x 24 columns]

# %% [markdown]
# # Step 3: Fetch Second Dataset (Health Expenditure that you want)

# %%
url_expenditure = (
    "https://sdmx.oecd.org/public/rest/data/"
    "OECD.ELS.HD,DSD_SHA@DF_SHA,1.0/"
    ".A.EXP_HEALTH.PT_B1GQ._T.._T.._T.../2015"
    "?format=csvfilewithlabels"
)

response_expenditure = requests.get(url_expenditure, headers=headers)
response_expenditure.raise_for_status()

df_expenditure = pd.read_csv(StringIO(response_expenditure.text))
print(f"✅ Health Expenditure dataset: {df_expenditure.shape[0]} rows, {df_expenditure.shape[1]} columns.")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       1 url_expenditure = (
#       2     "https://sdmx.oecd.org/public/rest/data/"
#       3     "OECD.ELS.HD,DSD_SHA@DF_SHA,1.0/"
#       4     ".A.EXP_HEALTH.PT_B1GQ._T.._T.._T.../2015"
#       5     "?format=csvfilewithlabels"
#       6 )
#       8 response_expenditure = requests.get(url_expenditure, headers=headers)
# ----> 9 response_expenditure.raise_for_status()
#      11 df_expenditure = pd.read_csv(StringIO(response_expenditure.text))
#      12 print(f"✅ Health Expenditure dataset: {df_expenditure.shape[0]} rows, {df_expenditure.shape[1]} columns.")
#
# File ~/myenv/lib/python3.13/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://sdmx.oecd.org/public/rest/data/OECD.ELS.HD,DSD_SHA@DF_SHA,1.0/.A.EXP_HEALTH.PT_B1GQ._T.._T.._T.../2015?format=csvfilewithlabels

# %%
df_expenditure
# Out:
#      STRUCTURE                     STRUCTURE_ID  \
# 0     DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 1     DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 2     DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 3     DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 4     DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# ...        ...                              ...
# 1912  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 1913  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 1914  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 1915  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
# 1916  DATAFLOW  OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)
#
#                         STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0     Health expenditure and financing      I      USA  United States    A
# 1     Health expenditure and financing      I      USA  United States    A
# 2     Health expenditure and financing      I      IND          India    A
# 3     Health expenditure and financing      I      IND          India    A
# 4     Health expenditure and financing      I      IND          India    A
# ...                                ...    ...      ...            ...  ...
# 1912  Health expenditure and financing      I      USA  United States    A
# 1913  Health expenditure and financing      I      USA  United States    A
# 1914  Health expenditure and financing      I      USA  United States    A
# 1915  Health expenditure and financing      I      USA  United States    A
# 1916  Health expenditure and financing      I      USA  United States    A
#
#      Frequency of observation     MEASURE      Measure  ... OBS_STATUS  \
# 0                      Annual  EXP_HEALTH  Expenditure  ...        NaN
# 1                      Annual  EXP_HEALTH  Expenditure  ...        NaN
# 2                      Annual  EXP_HEALTH  Expenditure  ...        NaN
# 3                      Annual  EXP_HEALTH  Expenditure  ...        NaN
# 4                      Annual  EXP_HEALTH  Expenditure  ...        NaN
# ...                       ...         ...          ...  ...        ...
# 1912                   Annual  EXP_HEALTH  Expenditure  ...        NaN
# 1913                   Annual  EXP_HEALTH  Expenditure  ...        NaN
# 1914                   Annual  EXP_HEALTH  Expenditure  ...        NaN
# 1915                   Annual  EXP_HEALTH  Expenditure  ...          E
# 1916                   Annual  EXP_HEALTH  Expenditure  ...        NaN
#
#      Observation status OBS_STATUS2 Observation status 2 OBS_STATUS3  \
# 0                   NaN         NaN                  NaN         NaN
# 1                   NaN         NaN                  NaN         NaN
# 2                   NaN         NaN                  NaN         NaN
# 3                   NaN         NaN                  NaN         NaN
# 4                   NaN         NaN                  NaN         NaN
# ...                 ...         ...                  ...         ...
# 1912                NaN         NaN                  NaN         NaN
# 1913                NaN         NaN                  NaN         NaN
# 1914                NaN         NaN                  NaN         NaN
# 1915    Estimated value         NaN                  NaN         NaN
# 1916                NaN         NaN                  NaN         NaN
#
#      Observation status 3 UNIT_MULT Unit multiplier DECIMALS Decimals
# 0                     NaN         0           Units        1      One
# 1                     NaN         0           Units        1      One
# 2                     NaN         0           Units        1      One
# 3                     NaN         0           Units        1      One
# 4                     NaN         0           Units        1      One
# ...                   ...       ...             ...      ...      ...
# 1912                  NaN         0           Units        1      One
# 1913                  NaN         0           Units        1      One
# 1914                  NaN         0           Units        1      One
# 1915                  NaN         0           Units        1      One
# 1916                  NaN         0           Units        1      One
#
# [1917 rows x 46 columns]

# %%
df_expenditure['STRUCTURE_NAME'].unique()
# Out:
# array(['Health expenditure and financing'], dtype=object)

# %% [markdown]
# # CouchDB is a NoSQL document database. It stores data in JSON format only.

# %%
# Step 4: SAFELY convert DataFrame to clean list of dicts (handling NaNs manually)

def safe_convert(df):
    """Safely convert a DataFrame to list of dicts, replacing NaN with None."""
    records = []
    for _, row in df.iterrows():
        doc = row.to_dict()
        clean_doc = {}
        for k, v in doc.items():
            if isinstance(v, float) and (math.isnan(v) or v in [float('inf'), float('-inf')]):
                clean_doc[k] = None
            else:
                clean_doc[k] = v
        records.append(clean_doc)
    return records

protection_records = safe_convert(df_protection)
expenditure_records = safe_convert(df_expenditure)

# %%
protection_records[0]
# Out:
# {'STRUCTURE': 'DATAFLOW',
#  'STRUCTURE_ID': 'OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)',
#  'STRUCTURE_NAME': 'Healthcare coverage',
#  'ACTION': 'I',
#  'REF_AREA': 'NLD',
#  'Reference area': 'Netherlands',
#  'FREQ': 'A',
#  'Frequency of observation': 'Annual',
#  'MEASURE': 'HIC',
#  'Measure': 'Health insurance coverage',
#  'UNIT_MEASURE': 'PT_POP',
#  'Unit of measure': 'Percentage of population',
#  'INSURANCE_TYPE': 'TPRIBASI',
#  'Insurance type': 'Public and primary voluntary health insurance',
#  'TIME_PERIOD': 2010,
#  'Time period': None,
#  'OBS_VALUE': 99.6,
#  'Observation value': None,
#  'OBS_STATUS': 'E',
#  'Observation status': 'Estimated value',
#  'UNIT_MULT': 0,
#  'Unit multiplier': 'Units',
#  'DECIMALS': None,
#  'Decimals': None}

# %%
expenditure_records[0]
# Out:
# {'STRUCTURE': 'DATAFLOW',
#  'STRUCTURE_ID': 'OECD.ELS.HD:DSD_SHA@DF_SHA(1.0)',
#  'STRUCTURE_NAME': 'Health expenditure and financing',
#  'ACTION': 'I',
#  'REF_AREA': 'USA',
#  'Reference area': 'United States',
#  'FREQ': 'A',
#  'Frequency of observation': 'Annual',
#  'MEASURE': 'EXP_HEALTH',
#  'Measure': 'Expenditure',
#  'UNIT_MEASURE': 'PT_B1GQ',
#  'Unit of measure': 'Percentage of GDP',
#  'FINANCING_SCHEME': '_T',
#  'Financing scheme': 'Total',
#  'FINANCING_SCHEME_REV': '_Z',
#  'Revenues of financing schemes': 'Not application',
#  'FUNCTION': '_T',
#  'Health function': 'Total',
#  'MODE_PROVISION': '_T',
#  'Mode of provision': 'Total',
#  'PROVIDER': '_T',
#  'Health care provider': 'Total',
#  'FACTOR_PROVISION': '_Z',
#  'Factor of provision': 'Not applicable',
#  'ASSET_TYPE': '_Z',
#  'Asset type': 'Not applicable',
#  'PRICE_BASE': '_Z',
#  'Price base': 'Not applicable',
#  'TIME_PERIOD': 1988.0,
#  'Time period': None,
#  'OBS_VALUE': 10.251,
#  'Observation value': None,
#  'BASE_PER': None,
#  'Base period': None,
#  'CURRENCY': None,
#  'Currency': None,
#  'OBS_STATUS': None,
#  'Observation status': None,
#  'OBS_STATUS2': None,
#  'Observation status 2': None,
#  'OBS_STATUS3': None,
#  'Observation status 3': None,
#  'UNIT_MULT': 0,
#  'Unit multiplier': 'Units',
#  'DECIMALS': 1,
#  'Decimals': 'One'}

# %%
# protection_records

# %% [markdown]
# # dump complete protection_records

# %%
import json
to_add = json.dumps(protection_records, indent=2)

# %%
to_add = []
for record in protection_records:
    st = json.dumps(record)
    to_add.append(json.loads(st))

# %%
to_add[0]
# Out:
# {'STRUCTURE': 'DATAFLOW',
#  'STRUCTURE_ID': 'OECD.ELS.HD:DSD_HEALTH_PROT@DF_HEALTH_PROT(1.0)',
#  'STRUCTURE_NAME': 'Healthcare coverage',
#  'ACTION': 'I',
#  'REF_AREA': 'NLD',
#  'Reference area': 'Netherlands',
#  'FREQ': 'A',
#  'Frequency of observation': 'Annual',
#  'MEASURE': 'HIC',
#  'Measure': 'Health insurance coverage',
#  'UNIT_MEASURE': 'PT_POP',
#  'Unit of measure': 'Percentage of population',
#  'INSURANCE_TYPE': 'TPRIBASI',
#  'Insurance type': 'Public and primary voluntary health insurance',
#  'TIME_PERIOD': 2010,
#  'Time period': None,
#  'OBS_VALUE': 99.6,
#  'Observation value': None,
#  'OBS_STATUS': 'E',
#  'Observation status': 'Estimated value',
#  'UNIT_MULT': 0,
#  'Unit multiplier': 'Units',
#  'DECIMALS': None,
#  'Decimals': None}

# %%
to_add = []
for record in expenditure_records:
    st = json.dumps(record)
    to_add.append(json.loads(st))

# %% [markdown]
# # for remaining datasets

# %% [markdown]
# # duplicating data in ecery write

# %%
# # -----------------------------------------------
# # 🚀 Start importing 3 more datasets (below your existing code)
# # -----------------------------------------------

# # Step 8: Safe NaN cleaner (already defined above, reuse safe_convert)
# # We can reuse the same safe_convert function we defined earlier

# # Step 9: Define your 3 new datasets
# new_datasets = [
#     # {
#     # "url": "https://sdmx.oecd.org/public/rest/data/OECD.ELS.HD,DSD_SHA@DF_SHA_FS,1.0/.A.REVENUE.PT_EXP_FS._T.FS1+FS3._T._T._T/2015?format=csvfilewithlabels",
#     # "doc_id": "health_expenditure_revenue_2015",
#     # "dataset_name": "Health Expenditure Revenue 2015"
#     # },
    
#     {
#         "url": "https://sdmx.oecd.org/public/rest/data/OECD.ELS.HD,DSD_SHA@DF_SHA_FP,1.0/.A..PT_EXP_PRV.....HP1.FP1../2010?format=csvfilewithlabels",
#         "doc_id": "health_expenditure_private_financing_2010",
#         "dataset_name": "Health Expenditure Private Financing 2010"
#     },
#     {
#         "url": "https://sdmx.oecd.org/public/rest/data/OECD.ELS.HD,DSD_SHA@DF_SHA_HK,1.0/.A.CAPITAL_FORM.PT_B1GQ....._T.._T./2015?format=csvfilewithlabels",
#         "doc_id": "health_expenditure_capital_formation_2015",
#         "dataset_name": "Health Expenditure Capital Formation 2015"
#     }
# ]

# headers = {
#     "User-Agent": "Mozilla/5.0"
# }

# # Step 10: Loop through and upload each new dataset
# for dataset in new_datasets:
#     try:
#         print(f"\n📥 Downloading {dataset['dataset_name']}...")
#         response = requests.get(dataset["url"], headers=headers)
#         response.raise_for_status()

#         df = pd.read_csv(StringIO(response.text))
#         print(f"✅ Downloaded {df.shape[0]} rows and {df.shape[1]} columns.")

#         # Clean NaNs safely
#         cleaned_data = safe_convert(df)

#         # # Create document
#         # document = {
#         #     "_id": dataset["doc_id"],
#         #     "dataset_name": dataset["dataset_name"],
#         #     "rows": cleaned_data
#         # }

        

#         # Upload document
#         try:
#             # db.save(document)
#             for a in cleaned_data:
#                 db.save(a)
#             print("data loaded")
#             # print(f"✅ Uploaded '{dataset['dataset_name']}' as document '{dataset['doc_id']}'.")
#         # except couchdb.http.ResourceConflict:
#         #     # print(f"⚡ Document with ID '{dataset['doc_id']}' already exists. Skipping upload.")
#         except Exception as e:
#             print(f"An error occurred: {e}")

#     except Exception as e:
#         # print(f"❌ Error uploading {dataset['dataset_name']}: {e}")
#         print(f" Outer error: An error occurred: {e}")

# # # Step 11: Final check - list all documents in CouchDB
# # print("\n📋 Updated list of documents in CouchDB:")
# # for doc_id in db:
# #     print(f"- {doc_id}")
# Out:
# 📥 Downloading Health Expenditure Private Financing 2010...
# ✅ Downloaded 62 rows and 46 columns.
# data loaded
#
# 📥 Downloading Health Expenditure Capital Formation 2015...
# ✅ Downloaded 1109 rows and 46 columns.
# data loaded

# %% [markdown]
# # Step 1: Read/Download and Clean Data (Run Once Per Dataset)

# %%
import requests
import pandas as pd
from io import StringIO

headers = {"User-Agent": "Mozilla/5.0"}
new_datasets = [
    {
        "url": "https://sdmx.oecd.org/public/rest/data/OECD.ELS.HD,DSD_SHA@DF_SHA_FP,1.0/.A..PT_EXP_PRV.....HP1.FP1../2010?format=csvfilewithlabels",
        "doc_id": "health_expenditure_private_financing_2010",
        "dataset_name": "Health Expenditure Private Financing 2010"
    },
    {
        "url": "https://sdmx.oecd.org/public/rest/data/OECD.ELS.HD,DSD_SHA@DF_SHA_HK,1.0/.A.CAPITAL_FORM.PT_B1GQ....._T.._T./2015?format=csvfilewithlabels",
        "doc_id": "health_expenditure_capital_formation_2015",
        "dataset_name": "Health Expenditure Capital Formation 2015"
    }
]

# This will store cleaned data for each dataset
cleaned_datasets = {}

for dataset in new_datasets:
    try:
        print(f"\n📥 Downloading {dataset['dataset_name']}...")
        response = requests.get(dataset["url"], headers=headers)
        response.raise_for_status()
        df = pd.read_csv(StringIO(response.text))
        print(f"✅ Downloaded {df.shape[0]} rows and {df.shape[1]} columns.")

        # Clean NaNs safely
        cleaned_data = safe_convert(df)
        cleaned_datasets[dataset['doc_id']] = cleaned_data

    except Exception as e:
        print(f"❌ Error downloading/cleaning {dataset['dataset_name']}: {e}")
# Out:
# 📥 Downloading Health Expenditure Private Financing 2010...
# ✅ Downloaded 62 rows and 46 columns.
#
# 📥 Downloading Health Expenditure Capital Formation 2015...
# ✅ Downloaded 1109 rows and 46 columns.

# %% [markdown]
# # Step 2: Write/Upload Cleaned Data to CouchDB (Run Once Per Dataset)

# %%
import couchdb

# Connect to CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984/')
db = couch['oecd_health_expenditure']

for doc_id, records in cleaned_datasets.items():
    print(f"\n⬆️ Uploading records for {doc_id}...")
    uploaded, skipped = 0, 0
    for record in records:
        # Set a unique _id for each record (for example, based on a unique field or a combination)
        # Here, let's assume 'REF_AREA' and 'TIME_PERIOD' are unique for each record
        unique_id = f"{doc_id}_{record.get('REF_AREA', '')}_{record.get('TIME_PERIOD', '')}"
        record['_id'] = unique_id

        try:
            db.save(record)
            uploaded += 1
        except couchdb.http.ResourceConflict:
            # Record already exists, skip to avoid duplicate
            skipped += 1
        except Exception as e:
            print(f"❌ Error uploading record: {e}")
    print(f"✅ Uploaded: {uploaded}, Skipped (already exists): {skipped}")
# Out:
# ⬆️ Uploading records for health_expenditure_private_financing_2010...
# ✅ Uploaded: 0, Skipped (already exists): 62
#
# ⬆️ Uploading records for health_expenditure_capital_formation_2015...
# ✅ Uploaded: 0, Skipped (already exists): 1109
